# %%
print("hello")

# %%
import sentence_transformers

print(sentence_transformers.__version__)

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\aarav\Desktop\AI-Powered Search Engine\.venv\Scripts\python.exe
